# %%
#importing all relevant modules
import pandas as pd
from matplotlib import pyplot as plt

import scipy.stats as st


cdcPath = "Resources/COVID-19_Case_Surveillance_Public_Use_Data.csv"

# %%
cdcDf = pd.read_csv(cdcPath, low_memory=False)

cdcDf
# Out:
#         cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# 0          2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1          2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2          2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3          2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4          2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# ...               ...         ...         ...                        ...
# 8405074    2020/10/22         NaN         NaN              Probable Case
# 8405075    2020/10/25         NaN         NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN         NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN         NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN         NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# ...

# %%
#Checking values in Race and Ethnicity
cdcDf['Race and ethnicity (combined)'].value_counts()
# Out:
# Unknown                                                 2781176
# White, Non-Hispanic                                     2599410
# Hispanic/Latino                                         1195739
# Black, Non-Hispanic                                      736584
# Missing                                                  601519
# Multiple/Other, Non-Hispanic                             270509
# Asian, Non-Hispanic                                      143080
# American Indian/Alaska Native, Non-Hispanic               59842
# Native Hawaiian/Other Pacific Islander, Non-Hispanic      17213
# Name: Race and ethnicity (combined), dtype: int64

# %%
#dropping unnecessary columns
cutCdcDf = cdcDf.drop(['pos_spec_dt', 'onset_dt','icu_yn','death_yn' ], axis=1)
#dropping missing or unknown data
ethMisDf = cutCdcDf[cutCdcDf['Race and ethnicity (combined)'] != 'Missing']
ethUnkDf = ethMisDf[ethMisDf['Race and ethnicity (combined)'] != 'Unknown']
ethUnkDf
# Out:
#         cdc_report_dt             current_status      sex      age_group  \
# 0          2020/11/10  Laboratory-confirmed case     Male  10 - 19 Years
# 1          2020/11/14  Laboratory-confirmed case     Male  10 - 19 Years
# 2          2020/11/19  Laboratory-confirmed case     Male  10 - 19 Years
# 3          2020/11/14  Laboratory-confirmed case     Male  10 - 19 Years
# 4          2020/11/13  Laboratory-confirmed case     Male  10 - 19 Years
# ...               ...                        ...      ...            ...
# 8404715    2020/09/05              Probable Case  Missing  30 - 39 Years
# 8404716    2020/09/05  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404717    2020/10/30  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404718    2020/09/28  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404719    2020/11/10  Laboratory-confirmed case  Missing  30 - 39 Years
#
#         Race and ethnicity (combined)  hosp_yn medcond_yn
# ...

# %%
#Checking values in the Age Groups
ethUnkDf['age_group'].value_counts()
# Out:
# 20 - 29 Years    951360
# 30 - 39 Years    799407
# 40 - 49 Years    742803
# 50 - 59 Years    727465
# 60 - 69 Years    531308
# 10 - 19 Years    503431
# 70 - 79 Years    316264
# 80+ Years        254563
# 0 - 9 Years      185198
# Unknown           10507
# Name: age_group, dtype: int64

# %%
#Dropping unknown values from the age groups
unkAgeDf = ethUnkDf[ethUnkDf['age_group'] != 'Unknown']
unkAgeDf
# Out:
#         cdc_report_dt             current_status      sex      age_group  \
# 0          2020/11/10  Laboratory-confirmed case     Male  10 - 19 Years
# 1          2020/11/14  Laboratory-confirmed case     Male  10 - 19 Years
# 2          2020/11/19  Laboratory-confirmed case     Male  10 - 19 Years
# 3          2020/11/14  Laboratory-confirmed case     Male  10 - 19 Years
# 4          2020/11/13  Laboratory-confirmed case     Male  10 - 19 Years
# ...               ...                        ...      ...            ...
# 8404715    2020/09/05              Probable Case  Missing  30 - 39 Years
# 8404716    2020/09/05  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404717    2020/10/30  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404718    2020/09/28  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404719    2020/11/10  Laboratory-confirmed case  Missing  30 - 39 Years
#
#         Race and ethnicity (combined)  hosp_yn medcond_yn
# ...

# %%
#Checking hospitilization values
unkAgeDf['hosp_yn'].value_counts()
# Out:
# No         2591276
# Missing    1556663
# Unknown     443552
# Yes         420386
# Name: hosp_yn, dtype: int64

# %%
#Dropping missing and unknown values from hospitilization
misHospDf = unkAgeDf[dropUnkDf['hosp_yn'] != 'Missing']
unkHospDf = misHospDf[misHospDf['hosp_yn'] != 'Unknown']
unkHospDf
# Out:
# /Users/ntarver/opt/anaconda3/envs/jupyterEnv/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#         cdc_report_dt             current_status      sex      age_group  \
# 0          2020/11/10  Laboratory-confirmed case     Male  10 - 19 Years
# 1          2020/11/14  Laboratory-confirmed case     Male  10 - 19 Years
# 2          2020/11/19  Laboratory-confirmed case     Male  10 - 19 Years
# 4          2020/11/13  Laboratory-confirmed case     Male  10 - 19 Years
# 6          2020/11/14  Laboratory-confirmed case     Male  10 - 19 Years
# ...               ...                        ...      ...            ...
# 8404705    2020/07/21  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404706    2020/11/08  Laboratory-confirmed case  Missing  30 - 39 Years
# 8404713    2020/11/19  Laboratory-confirmed case  Missing  30 - 39 Years
# ...

# %%
#Checking values for medical conditions
unkHospDf['medcond_yn'].value_counts()
# Out:
# Missing    1811865
# Yes         579151
# No          459692
# Unknown     160954
# Name: medcond_yn, dtype: int64

# %%
#Dropping missing and unknown values from conditions
misMedDf = unkHospDf[unkHospDf['medcond_yn'] != 'Missing']
unkMedDf = misMedDf[misMedDf['medcond_yn'] != 'Unknown']
unkMedDf
# Out:
#         cdc_report_dt             current_status     sex      age_group  \
# 0          2020/11/10  Laboratory-confirmed case    Male  10 - 19 Years
# 1          2020/11/14  Laboratory-confirmed case    Male  10 - 19 Years
# 2          2020/11/19  Laboratory-confirmed case    Male  10 - 19 Years
# 4          2020/11/13  Laboratory-confirmed case    Male  10 - 19 Years
# 11         2020/11/09  Laboratory-confirmed case    Male  10 - 19 Years
# ...               ...                        ...     ...            ...
# 8404622    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
# 8404623    2020/06/08  Laboratory-confirmed case  Female  30 - 39 Years
# 8404634    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
# 8404659    2020/06/01  Laboratory-confirmed case  Female  30 - 39 Years
# 8404671    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
#
#         Race and ethnicity (combined) hosp_yn medcond_yn
# ...

# %%
#Checking values in the sex column
unkMedDf['sex'].value_counts()
# Out:
# Female     550587
# Male       483751
# Unknown      3403
# Missing      1010
# Other          83
# Name: sex, dtype: int64

# %%
#removing missing and unknown values from the sex column
misSexDf = unkMedDf[unkMedDf['sex'] != 'Missing']
unkSexDf = misSexDf[misMedDf['sex'] != 'Unknown']

unkSexDf
# Out:
# /Users/ntarver/opt/anaconda3/envs/jupyterEnv/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#         cdc_report_dt             current_status     sex      age_group  \
# 0          2020/11/10  Laboratory-confirmed case    Male  10 - 19 Years
# 1          2020/11/14  Laboratory-confirmed case    Male  10 - 19 Years
# 2          2020/11/19  Laboratory-confirmed case    Male  10 - 19 Years
# 4          2020/11/13  Laboratory-confirmed case    Male  10 - 19 Years
# 11         2020/11/09  Laboratory-confirmed case    Male  10 - 19 Years
# ...               ...                        ...     ...            ...
# 8404622    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
# 8404623    2020/06/08  Laboratory-confirmed case  Female  30 - 39 Years
# 8404634    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
# 8404659    2020/06/01  Laboratory-confirmed case  Female  30 - 39 Years
# ...

# %%
#Checking values in the status column
unkSexDf['current_status'].value_counts()
# Out:
# Laboratory-confirmed case    991978
# Probable Case                 42452
# Name: current_status, dtype: int64

# %%
#Removing non-laboratory confirmed cases
cleanedCdcDf = unkSexDf[unkSexDf['current_status'] != 'Probable Case']
cleanedCdcDf
# Out:
#         cdc_report_dt             current_status     sex      age_group  \
# 0          2020/11/10  Laboratory-confirmed case    Male  10 - 19 Years
# 1          2020/11/14  Laboratory-confirmed case    Male  10 - 19 Years
# 2          2020/11/19  Laboratory-confirmed case    Male  10 - 19 Years
# 4          2020/11/13  Laboratory-confirmed case    Male  10 - 19 Years
# 11         2020/11/09  Laboratory-confirmed case    Male  10 - 19 Years
# ...               ...                        ...     ...            ...
# 8404622    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
# 8404623    2020/06/08  Laboratory-confirmed case  Female  30 - 39 Years
# 8404634    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
# 8404659    2020/06/01  Laboratory-confirmed case  Female  30 - 39 Years
# 8404671    2020/06/10  Laboratory-confirmed case  Female  30 - 39 Years
#
#         Race and ethnicity (combined) hosp_yn medcond_yn
# ...
